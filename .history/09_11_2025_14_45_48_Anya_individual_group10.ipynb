# %% [markdown]
# Data Science Project: Planning Stage (Individual Portion)

# %% [markdown]
# Data Description:
#
# A UBC research group is collecting data on how people play videogames. Below is a summary of the datasets:
#
# Player Data: players.csv
#
# Observations(rows): 196
# Variables(Columns): 7
#
# Varaible Information:
# |Variable Name| Type    | Description|
# |------------|----------|--------|
# |experience  |Character |Player's self reported experience level|
# |subscribe   |Logical   |Whether the player subscribed to a game-related newsletter(True/False)|
# |hashedEmail |Character |Player's unique hashed anonymous email|
# |played_hours|Double    |Player's total hours in the game|
# |name        |Character |Player's in game name|
# |gender      |Factor    |Player self reported gender|
# |age         |Integer   |Player age in years(no decimals)|
#
# Additional Details:
# - Experience level is self reported and may be biased resulting in inacurate representation.
# - Sampling bias may affect results.
# - There is a not applicable (NA) within the data which may cause issues when analysing.
# - The gender variable is self reported by the players which may cause
# - Age and played_hours may have outliers causing the results to be skewed

# %%
library(tidyverse)

url<- "https://raw.githubusercontent.com/ajones200/dsci100_individual/refs/heads/main/players.csv?token=GHSAT0AAAAAADO2FMPSWQLQGBNFINOTBF7I2IQ76ZQ"
players_data<- read_csv(url) 
head(players_data)

# %% [markdown]
# Questions:
# Broad question: What player characteristics and behaviours are most predictive of subscribing to a game-related newsletter, and how do these features differ between various player types?
#
# Specific question: Can a players total playtime(played_hours), number of sessions(number_of_sessions), experience level (experience) and age(age) predict whether they will subscribe to the game-related newsletter(subscribe)?
#
#
# Methods and Plan:

# %% [markdown]
# Exploratory Data Analysis and Visualization:

# %%
Data Wrangling:

Libraries:


library(repr)
library(ggplot2)
source("cleanup.R")



library(tabulizer)

Load the dataset:

url<- "https://raw.githubusercontent.com/ajones200/dsci100_individual/refs/heads/main/players.csv?token=GHSAT0AAAAAADO2FMPSWQLQGBNFINOTBF7I2IQ76ZQ"
players_data<- read_csv(url) 

url<- 



Tidy data:


Mean value for each quantitative variable:

mean_hours_played<- 

mean_age<- 


Visualizations and Insights:
